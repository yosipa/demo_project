# %%
import pandas as pd
from sklearn.impute import SimpleImputer
import numpy as np

# %%
df = pd.read_csv("../data/raw/bank-additional-full.csv", delimiter=";")
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
df.shape
# Out:
# (41188, 21)

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (41176, 21)

# %%
df = df.dropna()

# %%
Set impute strategy

# %%
impute_missing = SimpleImputer(missing_values="unknown", strategy="most_frequent")

# %% [markdown]
# Check if we should delete or impute "unknown" value for job - if more than 10% -> impute

# %%
df.job.value_counts()
# Out:
# admin.           10419
# blue-collar       9253
# technician        6739
# services          3967
# management        2924
# retired           1718
# entrepreneur      1456
# self-employed     1421
# housemaid         1060
# unemployed        1014
# student            875
# unknown            330
# Name: job, dtype: int64

# %%
df = df.drop(df[df.job == "unknown"].index)
df.shape

# %% [markdown]
# Check if we should delete or impute "unknown" value for marital - if more than 10% -> impute

# %%
df.marital.value_counts()
# Out:
# married     24921
# single      11564
# divorced     4611
# unknown        80
# Name: marital, dtype: int64

# %%
df = df.drop(df[df.marital == "unknown"].index)
df.shape

# %% [markdown]
# Check if we should delete or impute "unknown" value for default - if more than 10% -> impute

# %%
df.default.value_counts()
# Out:
# no         32588
# unknown     8597
# yes            3
# Name: default, dtype: int64

# %% [raw]
# Number of unknown elements is bigger than 10% -> impute missing values

# %%
df["default"] = impute_missing.fit_transform(df[["default"]])
df.default.value_counts()

# %% [markdown]
# Check if we should delete or impute "unknown" value for loan - if more than 10% -> impute

# %%
df.loan.value_counts()
# Out:
# no         33950
# yes         6248
# unknown      990
# Name: loan, dtype: int64

# %%
df = df.drop(df[df.loan == "unknown"].index)
df.shape
# Out:
# no         33938
# yes         6248
# unknown      990
# Name: loan, dtype: int64

# %% [markdown]
# Check if we should delete or impute "unknown" value for housing - if more than 10% -> impute

# %%
df.housing.value_counts()
# Out:
# yes        21571
# no         18615
# unknown      990
# Name: housing, dtype: int64

# %%
df = df.drop(df[df.housing == "unknown"].index)
df.shape

# %% [markdown]
# Check if we should delete or impute "unknown" value for age - if more than 10% -> impute

# %%
df.age.value_counts()
# Out:
# 31    1947
# 32    1846
# 33    1833
# 36    1780
# 35    1759
#       ...
# 89       2
# 91       2
# 87       1
# 94       1
# 95       1
# Name: age, Length: 78, dtype: int64

# %% [markdown]
# Check if we should delete or impute "unknown" value for education - if more than 10% -> impute

# %%
df.education.value_counts()
# Out:
# university.degree      12168
# high.school             9515
# basic.9y                6045
# professional.course     5243
# basic.4y                4176
# basic.6y                2292
# unknown                 1731
# illiterate                18
# Name: education, dtype: int64

# %%
df = df.drop(df[df.education == "unknown"].index)
df.shape

# %% [markdown]
# Check if we should delete or impute "unknown" value for contact - if more than 10% -> impute

# %%
df.contact.value_counts()
# Out:
# cellular     26144
# telephone    15044
# Name: contact, dtype: int64

# %% [markdown]
# Check if we should delete or impute "unknown" value for month - if more than 10% -> impute

# %%
df.month.value_counts()
# Out:
# may    13769
# jul     7174
# aug     6178
# jun     5318
# nov     4101
# apr     2632
# oct      718
# sep      570
# mar      546
# dec      182
# Name: month, dtype: int64

# %%
df
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
df.to_csv("../data/clean/bank-additional-clean.csv", index=False)
df
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %% [markdown]
# Delete all unknown values

# %%
# Out:
# no     41185
# yes        3
# Name: default, dtype: int64

# %%
# Out:
#        age          job  marital            education default housing loan  \
# 0       56    housemaid  married             basic.4y      no      no   no
# 1       57     services  married          high.school      no      no   no
# 2       37     services  married          high.school      no     yes   no
# 3       40       admin.  married             basic.6y      no      no   no
# 4       56     services  married          high.school      no      no  yes
# ...    ...          ...      ...                  ...     ...     ...  ...
# 41183   73      retired  married  professional.course      no     yes   no
# 41184   46  blue-collar  married  professional.course      no      no   no
# 41185   56      retired  married    university.degree      no     yes   no
# 41186   44   technician  married  professional.course      no      no   no
# 41187   74      retired  married  professional.course      no     yes   no
#
# ...

# %%
df.default.value_counts()

# %%
impute_missing=SimpleImputer(missing_values="unknown", strategy="mean")
df["default"] = impute_missing.fit_transform(df[["default"]]) 
df.head
# Out:
#   File "<ipython-input-57-5b32bfcd2f38>", line 1
#     impute_missing=SimpleImputer(missing_values="unknown", strategy="mean")
#                                                                   ^
# SyntaxError: invalid character in identifier

# %%
df = df.drop(df[df.marital == "unknown"].index)
df = df.drop(df[df.loan == "unknown"].index)
df = df.drop(df[df.education == "unknown"].index)
df = df.drop(df[df.age == "unknown"].index)
df = df.drop(df[df.education == "unknown"].index)
df = df.drop(df[df.education == "unknown"].index)
df.shape
